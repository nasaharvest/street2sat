# %% [markdown]
# <a href="https://colab.research.google.com/github/nasaharvest/street2sat/blob/point-plotting/new_point_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Point Plotting
#
# **Author**: Anjali Paliyam
#
# **Last Modified**: Sep 9, 2024
#
# **Description**: New method to plot crop type points using Kenyan admin boundaries

# %%
import geopandas as gpd
from shapely.geometry import Point

gdf_gadm2 = gpd.read_file("https://geodata.ucdavis.edu/gadm/gadm4.1/json/gadm41_KEN_2.json")
geometry = [Point(xy) for xy in zip(df["lon"], df["lat"])]
gdf_points = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

import matplotlib.pyplot as plt

ax = gdf_gadm2.plot(facecolor="lightgray", edgecolor="black", figsize=(15, 15))

gdf_points.plot(
    ax=ax,
    marker='o',
    color='red',
    markersize=1,
)

plt.title("Crop Type Points within Kenyan Administrative Boundaries", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Crop Type Points within Kenyan Administrative Boundaries')
