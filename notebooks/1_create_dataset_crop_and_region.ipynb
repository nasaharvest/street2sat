# %%
from google.cloud import firestore
from google.cloud import storage, aiplatform
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from yolov5 import detect
import sys
import yaml
import os
import shutil
import reverse_geocoder as rg
import random
from tqdm import tqdm
import collections
from datetime import datetime

# might be useful for changing all JPG to jpg
# for x in `du -a | cut -d '/' -f2- | grep JPG`; do mv "$x" "${x%.JPG}.jpg"; done

# Initialize connections to cloud storage and database
# !gcloud auth login
# !gcloud config set account <>
# !gcloud config set project bsos-geog-harvest1
# !gcloud auth application-default login

# %% [markdown]
# # Create Dataset Based On Crop And Region
#
# **Author:** Madhava Paliyam (madhavapaliyam@gmail.com)
#
# **Description:** Creates a dataset based on a crop or region that we want to improve in
#
#
#
# **Inputs**: Parameters for yolov5 detection, region to query, crop to query
#
# **Outputs**: A dataset onto gs://street2sat-gcloud-labeling bucket with dataset and AI platform dataset.

# %%
##### SET PARAMETERS HERE #####

query_for_crop = 'banana' # choose from any of the available crops
query_for_region = 'KE' # choose from country code : 'KE', 'UG', 'US'
num_of_images = 250 # num images to search 


# yolov5 Parameters: 
# yaml file describing data for trained model
folder = '/gpfs/data1/cmongp1/mpaliyam/street2sat/data'
dataset_name = 'DATASET_2022-02-28_01:13:06_474346'
yaml_file = os.path.join(folder, dataset_name, 'data_info.yaml')
weights= '/gpfs/data1/cmongp1/mpaliyam/street2sat/yolov5/runs/train/exp18/weights/best.pt'   # model.pt path(s)

data = yaml_file # dataset.yaml path
imgsz= 640  # inference size (height, width)
conf_thres = 0.05  # confidence threshold
iou_thres = 0.05  # NMS IOU threshold
max_det = 1000  # maximum detections per image
project = 'runs/detect'  # save results to project/name
name ='exp'  # save results to project/name
save_dir = os.path.join(f'crop_{query_for_crop}_region_{query_for_region}') # downloaded images will be saved to save_dir 

# !dvc pull -q -f

# %%
# read csv 
all_paths = pd.read_csv('gs://street2sat-database-csv/database-info.csv')
# we want images not already being labeled
all_paths = all_paths[all_paths['being_labeled'] == False]
# and also images that are not in test set 
all_paths = all_paths[all_paths['test_set'] == False]
# Out:
# /home/paliyamm/.conda/envs/lacuna/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# randomly sample images within country
potential_images = all_paths[all_paths['cc'] == query_for_region].sample(num_of_images)
potential_images.head()
# Out:
#         Unnamed: 0                                          input_img  latitude  longitude  being_labeled country       admin1 admin2  cc  location  test_set                       time  focal_length  pixel_height
# 53235        53235  gs://street2sat-uploaded/KENYA/2021-08-03-T1/G... -1.084484  35.913396          False   KENYA        Narok    NaN  KE     Narok     False  2021-08-03 15:37:08+00:00             3          2028
# 106114      106114  gs://street2sat-uploaded/KENYA/2021_07_18_T2/1...  0.676725  34.300967          False   KENYA        Busia    NaN  KE    Malaba     False  2021-07-18 14:34:22+00:00             3          2028
# 114165      114165  gs://street2sat-uploaded/KENYA/2021_07_19_T2/1...  0.090078  34.639646          False   KENYA        Siaya    NaN  KE      Yala     False  2021-07-19 15:33:00+00:00             3          2028
# 38475        38475  gs://street2sat-uploaded/KENYA/2021-07-27-T1/G... -0.593231  34.553229          False   KENYA     Homa Bay    NaN  KE  Homa Bay     False  2021-07-27 14:01:37+00:00             3          2028
# 89002        89002  gs://street2sat-uploaded/KENYA/2021_07_14_T2/1...  0.831008  35.002379          False   KENYA  Trans Nzoia    NaN  KE    Kitale     False  2021-07-14 10:57:37+00:00             3          2028

# %%
# open connection to google cloud 
client = storage.Client()
gcloud_labeling_bucket_str = 'street2sat-gcloud-labeling'
gcloud_uploaded_bucket_str = 'street2sat-uploaded'

region_to_folder = {'KE': 'KENYA', 'US': 'USA', 'UG': 'Uganda', '':''}

gcloud_uploaded_bucket = client.bucket(gcloud_uploaded_bucket_str)


classes_dict = {}
with open('../street2sat_utils/crop_info/classes.txt') as classes_file: 
    for i, line in enumerate(classes_file):
        classes_dict[line.strip()] = i

# %%
# create directory to save images to 
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
# download images 
for i,item in potential_images.iterrows(): 
    blob = gcloud_uploaded_bucket.blob(item['input_img'].replace('gs://street2sat-uploaded/', ''))
    blob.download_to_filename(os.path.join(save_dir, f"{i}.jpg"))

# %% [markdown]
# #### Run detect.py
#
# Configure conf_thres and iou_thres to adjust the amount/quality of bounding boxes returned.

# %%
conf_thres = conf_thres
iou_thres = iou_thres

# runs the detect script from yolov5 libary
to_parse = f"detect.py " \
            + f"--weights {weights} " \
            + f"--source {save_dir} " \
            + f"--imgsz {imgsz} " \
            + f"--conf-thres {conf_thres} " \
            + f"--iou-thres {iou_thres} " \
            + f"--classes {classes_dict[query_for_crop]} " \
            + f"--max-det {max_det} " \
            + f"--project {project} " \
            + f"--name {name} " \
            + f"--exist-ok " \
            + f"--save-crop " \
            + f"--save-txt " \
            + f"--save-conf " \

to_parse = to_parse.split()
sys.argv = to_parse 
detect.main()
# Out:
# detect: weights=['/gpfs/data1/cmongp1/mpaliyam/street2sat/yolov5/runs/train/exp18/weights/best.pt'], source=crop_banana_region_KE, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.05, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=True, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# INFO:yolov5.utils.torch_utils:YOLOv5 🚀 2022-2-16 torch 1.10.2+cu102 CUDA:0 (Tesla V100-PCIE-16GB, 16160.5MB)
#
# INFO:models.yolo:Fusing layers...
# INFO:yolov5.utils.torch_utils:Model Summary: 369 layers, 20919810 parameters, 0 gradients, 48.2 GFLOPs
# image 1/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/100073.jpg: 480x640 Done. (0.011s)
# image 2/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/100652.jpg: 480x640 Done. (0.013s)
# image 3/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/10127.jpg: 480x640 Done. (0.012s)
# image 4/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/103975.jpg: 480x640 Done. (0.011s)
# image 5/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104643.jpg: 480x640 Done. (0.015s)
# image 6/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104962.jpg: 480x640 Done. (0.012s)
# image 7/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104990.jpg: 480x640 Done. (0.011s)
# image 8/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105049.jpg: 480x640 Done. (0.010s)
# image 9/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105186.jpg: 480x640 Done. (0.011s)
# image 10/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105277.jpg: 480x640 Done. (0.011s)
# image 11/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106114.jpg: 480x640 Done. (0.011s)
# image 12/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106129.jpg: 480x640 Done. (0.010s)
# image 13/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106173.jpg: 480x640 Done. (0.014s)
# image 14/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106867.jpg: 480x640 Done. (0.011s)
# image 15/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/107007.jpg: 480x640 Done. (0.010s)
# image 16/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/107049.jpg: 480x640 Done. (0.011s)
# image 17/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108178.jpg: 480x640 Done. (0.010s)
# image 18/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108753.jpg: 480x640 Done. (0.010s)
# image 19/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/109099.jpg: 480x640 Done. (0.010s)
# image 20/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/109379.jpg: 480x640 Done. (0.011s)
# image 21/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/110078.jpg: 480x640 Done. (0.010s)
# image 22/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/110697.jpg: 480x640 Done. (0.010s)
# image 23/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/111208.jpg: 480x640 Done. (0.010s)
# image 24/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/111882.jpg: 480x640 Done. (0.010s)
# image 25/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112502.jpg: 480x640 Done. (0.011s)
# image 26/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112520.jpg: 480x640 Done. (0.010s)
# image 27/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/113060.jpg: 480x640 Done. (0.010s)
# image 28/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/113154.jpg: 480x640 Done. (0.010s)
# image 29/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/113835.jpg: 480x640 Done. (0.010s)
# image 30/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/114165.jpg: 480x640 Done. (0.010s)
# image 31/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115205.jpg: 480x640 Done. (0.011s)
# image 32/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115612.jpg: 480x640 Done. (0.010s)
# image 33/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115713.jpg: 480x640 Done. (0.010s)
# image 34/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115715.jpg: 480x640 Done. (0.010s)
# image 35/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/116127.jpg: 480x640 Done. (0.011s)
# image 36/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/117119.jpg: 480x640 Done. (0.010s)
# image 37/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/117276.jpg: 480x640 Done. (0.010s)
# image 38/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/117832.jpg: 480x640 Done. (0.014s)
# image 39/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/118011.jpg: 480x640 Done. (0.012s)
# image 40/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/118355.jpg: 480x640 Done. (0.010s)
# image 41/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/118594.jpg: 480x640 Done. (0.010s)
# image 42/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/118954.jpg: 480x640 Done. (0.010s)
# image 43/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/119323.jpg: 480x640 Done. (0.010s)
# image 44/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/119704.jpg: 480x640 Done. (0.010s)
# image 45/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/120706.jpg: 480x640 Done. (0.010s)
# image 46/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/120833.jpg: 480x640 Done. (0.012s)
# image 47/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121297.jpg: 480x640 Done. (0.013s)
# image 48/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121309.jpg: 480x640 Done. (0.011s)
# image 49/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121384.jpg: 480x640 Done. (0.011s)
# image 50/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121768.jpg: 480x640 Done. (0.010s)
# image 51/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121797.jpg: 480x640 Done. (0.010s)
# image 52/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/121926.jpg: 480x640 Done. (0.010s)
# image 53/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/122530.jpg: 480x640 Done. (0.010s)
# image 54/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/122595.jpg: 480x640 Done. (0.010s)
# image 55/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/122650.jpg: 480x640 Done. (0.010s)
# image 56/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/122847.jpg: 480x640 Done. (0.010s)
# image 57/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123470.jpg: 480x640 Done. (0.010s)
# image 58/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123751.jpg: 480x640 Done. (0.014s)
# image 59/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/124926.jpg: 480x640 Done. (0.011s)
# image 60/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/12502.jpg: 480x640 Done. (0.011s)
# image 61/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/125482.jpg: 480x640 Done. (0.011s)
# image 62/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/126410.jpg: 480x640 Done. (0.011s)
# image 63/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127130.jpg: 480x640 Done. (0.013s)
# image 64/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127348.jpg: 480x640 Done. (0.011s)
# image 65/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127795.jpg: 480x640 Done. (0.010s)
# image 66/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127799.jpg: 480x640 Done. (0.011s)
# image 67/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127813.jpg: 480x640 Done. (0.010s)
# image 68/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128658.jpg: 480x640 Done. (0.012s)
# image 69/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128685.jpg: 480x640 Done. (0.010s)
# image 70/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128803.jpg: 480x640 Done. (0.010s)
# image 71/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/130046.jpg: 480x640 Done. (0.010s)
# image 72/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/130646.jpg: 480x640 Done. (0.011s)
# image 73/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/130763.jpg: 480x640 Done. (0.012s)
# image 74/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/130902.jpg: 480x640 Done. (0.010s)
# image 75/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/131160.jpg: 480x640 Done. (0.012s)
# image 76/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/13129.jpg: 480x640 Done. (0.017s)
# image 77/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/131372.jpg: 480x640 Done. (0.012s)
# image 78/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/132348.jpg: 480x640 Done. (0.010s)
# image 79/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/132473.jpg: 480x640 Done. (0.010s)
# image 80/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/14203.jpg: 480x640 Done. (0.011s)
# image 81/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/14585.jpg: 480x640 Done. (0.011s)
# image 82/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/14682.jpg: 480x640 Done. (0.011s)
# image 83/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/14894.jpg: 480x640 Done. (0.011s)
# image 84/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/15003.jpg: 480x640 Done. (0.011s)
# image 85/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/15046.jpg: 480x640 Done. (0.011s)
# image 86/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/15403.jpg: 480x640 Done. (0.011s)
# image 87/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1568.jpg: 480x640 Done. (0.011s)
# image 88/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/16228.jpg: 480x640 Done. (0.010s)
# image 89/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1722.jpg: 480x640 Done. (0.010s)
# image 90/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17564.jpg: 480x640 Done. (0.010s)
# image 91/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17728.jpg: 480x640 Done. (0.010s)
# image 92/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1960.jpg: 480x640 Done. (0.010s)
# image 93/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20613.jpg: 480x640 Done. (0.010s)
# image 94/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20975.jpg: 480x640 Done. (0.010s)
# image 95/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20991.jpg: 480x640 Done. (0.010s)
# image 96/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/21068.jpg: 480x640 4 bananas, Done. (0.011s)
# image 97/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/21251.jpg: 480x640 4 bananas, Done. (0.011s)
# image 98/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/21926.jpg: 480x640 Done. (0.012s)
# image 99/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/22480.jpg: 480x640 Done. (0.011s)
# image 100/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/22645.jpg: 480x640 Done. (0.010s)
# image 101/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/23310.jpg: 480x640 Done. (0.011s)
# image 102/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/23985.jpg: 480x640 Done. (0.010s)
# image 103/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/24019.jpg: 480x640 1 banana, Done. (0.010s)
# image 104/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/2537.jpg: 480x640 Done. (0.010s)
# image 105/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/25418.jpg: 480x640 2 bananas, Done. (0.010s)
# image 106/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/25909.jpg: 480x640 Done. (0.012s)
# image 107/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/26107.jpg: 480x640 1 banana, Done. (0.013s)
# image 108/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/26691.jpg: 480x640 Done. (0.010s)
# image 109/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/2709.jpg: 480x640 Done. (0.011s)
# image 110/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/27999.jpg: 480x640 Done. (0.011s)
# image 111/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/28058.jpg: 480x640 Done. (0.011s)
# image 112/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/28456.jpg: 480x640 Done. (0.011s)
# image 113/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/29541.jpg: 480x640 Done. (0.012s)
# image 114/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/29785.jpg: 480x640 Done. (0.012s)
# image 115/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/30453.jpg: 480x640 Done. (0.011s)
# image 116/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/30838.jpg: 480x640 Done. (0.010s)
# image 117/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/31134.jpg: 480x640 Done. (0.011s)
# image 118/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3140.jpg: 480x640 Done. (0.013s)
# image 119/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/31575.jpg: 480x640 Done. (0.011s)
# image 120/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/31779.jpg: 480x640 Done. (0.012s)
# image 121/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3232.jpg: 480x640 Done. (0.011s)
# image 122/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/32907.jpg: 480x640 Done. (0.010s)
# image 123/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/32947.jpg: 480x640 Done. (0.010s)
# image 124/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33321.jpg: 480x640 Done. (0.010s)
# image 125/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/35953.jpg: 480x640 Done. (0.010s)
# image 126/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3608.jpg: 480x640 Done. (0.011s)
# image 127/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/36136.jpg: 480x640 Done. (0.012s)
# image 128/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/36515.jpg: 480x640 Done. (0.012s)
# image 129/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/36855.jpg: 480x640 Done. (0.010s)
# image 130/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/37510.jpg: 480x640 Done. (0.011s)
# image 131/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/37543.jpg: 480x640 Done. (0.012s)
# image 132/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/38475.jpg: 480x640 Done. (0.010s)
# image 133/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/38834.jpg: 480x640 Done. (0.011s)
# image 134/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/39486.jpg: 480x640 Done. (0.011s)
# image 135/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/41406.jpg: 480x640 Done. (0.010s)
# image 136/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/41582.jpg: 480x640 Done. (0.012s)
# image 137/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/42420.jpg: 480x640 Done. (0.010s)
# image 138/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/4245.jpg: 480x640 Done. (0.010s)
# image 139/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/42464.jpg: 480x640 Done. (0.011s)
# image 140/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/42620.jpg: 480x640 Done. (0.010s)
# image 141/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/42783.jpg: 480x640 Done. (0.010s)
# image 142/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/42794.jpg: 480x640 Done. (0.010s)
# image 143/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/43439.jpg: 480x640 Done. (0.010s)
# image 144/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/43524.jpg: 480x640 Done. (0.010s)
# image 145/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/46008.jpg: 480x640 Done. (0.010s)
# image 146/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/46213.jpg: 480x640 Done. (0.010s)
# image 147/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/47174.jpg: 480x640 Done. (0.011s)
# image 148/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/47308.jpg: 480x640 Done. (0.010s)
# image 149/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/49654.jpg: 480x640 Done. (0.010s)
# image 150/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/50377.jpg: 480x640 Done. (0.011s)
# image 151/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5062.jpg: 480x640 Done. (0.010s)
# image 152/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/50904.jpg: 480x640 Done. (0.011s)
# image 153/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/52410.jpg: 480x640 Done. (0.011s)
# image 154/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/52618.jpg: 480x640 Done. (0.011s)
# image 155/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/53235.jpg: 480x640 Done. (0.011s)
# image 156/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5352.jpg: 480x640 Done. (0.011s)
# image 157/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/53897.jpg: 480x640 Done. (0.010s)
# image 158/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/54248.jpg: 480x640 Done. (0.010s)
# image 159/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/56095.jpg: 480x640 Done. (0.010s)
# image 160/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/56230.jpg: 480x640 Done. (0.010s)
# image 161/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5864.jpg: 480x640 Done. (0.010s)
# image 162/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5876.jpg: 480x640 Done. (0.010s)
# image 163/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5916.jpg: 480x640 Done. (0.010s)
# image 164/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/60539.jpg: 480x640 Done. (0.010s)
# image 165/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/60559.jpg: 480x640 Done. (0.010s)
# image 166/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6056.jpg: 480x640 Done. (0.010s)
# image 167/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/61385.jpg: 480x640 1 banana, Done. (0.011s)
# image 168/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/62216.jpg: 480x640 Done. (0.011s)
# image 169/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/63856.jpg: 480x640 Done. (0.010s)
# image 170/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/64191.jpg: 480x640 2 bananas, Done. (0.010s)
# image 171/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6509.jpg: 480x640 Done. (0.011s)
# image 172/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65566.jpg: 480x640 Done. (0.011s)
# image 173/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65681.jpg: 480x640 Done. (0.012s)
# image 174/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65785.jpg: 480x640 Done. (0.011s)
# image 175/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65872.jpg: 480x640 Done. (0.010s)
# image 176/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/66348.jpg: 480x640 Done. (0.011s)
# image 177/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6765.jpg: 480x640 Done. (0.011s)
# image 178/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/68116.jpg: 480x640 Done. (0.012s)
# image 179/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/68236.jpg: 480x640 Done. (0.010s)
# image 180/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6871.jpg: 480x640 Done. (0.010s)
# image 181/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71327.jpg: 480x640 Done. (0.010s)
# image 182/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71385.jpg: 480x640 Done. (0.010s)
# image 183/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71615.jpg: 480x640 Done. (0.010s)
# image 184/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/72200.jpg: 480x640 Done. (0.011s)
# image 185/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/72236.jpg: 480x640 Done. (0.010s)
# image 186/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/72296.jpg: 480x640 Done. (0.010s)
# image 187/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/73687.jpg: 480x640 Done. (0.010s)
# image 188/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/73753.jpg: 480x640 Done. (0.011s)
# image 189/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74307.jpg: 480x640 Done. (0.010s)
# image 190/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74772.jpg: 480x640 Done. (0.011s)
# image 191/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74892.jpg: 480x640 Done. (0.011s)
# image 192/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75235.jpg: 480x640 Done. (0.010s)
# image 193/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75335.jpg: 480x640 Done. (0.010s)
# image 194/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75799.jpg: 480x640 Done. (0.010s)
# image 195/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76359.jpg: 480x640 Done. (0.010s)
# image 196/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76580.jpg: 480x640 Done. (0.010s)
# image 197/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76860.jpg: 480x640 Done. (0.012s)
# image 198/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76940.jpg: 480x640 Done. (0.011s)
# image 199/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/7699.jpg: 480x640 Done. (0.013s)
# image 200/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/77694.jpg: 480x640 Done. (0.010s)
# image 201/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/78114.jpg: 480x640 Done. (0.011s)
# image 202/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/78333.jpg: 480x640 Done. (0.011s)
# image 203/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79113.jpg: 480x640 Done. (0.009s)
# image 204/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79276.jpg: 480x640 1 banana, Done. (0.011s)
# image 205/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79507.jpg: 480x640 Done. (0.009s)
# image 206/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/8065.jpg: 480x640 Done. (0.013s)
# image 207/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/80909.jpg: 480x640 Done. (0.011s)
# image 208/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/81312.jpg: 480x640 Done. (0.011s)
# image 209/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/8583.jpg: 480x640 Done. (0.012s)
# image 210/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/87675.jpg: 480x640 Done. (0.010s)
# image 211/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/87997.jpg: 480x640 Done. (0.012s)
# image 212/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88045.jpg: 480x640 Done. (0.010s)
# image 213/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/8866.jpg: 480x640 Done. (0.010s)
# image 214/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88799.jpg: 480x640 Done. (0.010s)
# image 215/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88920.jpg: 480x640 Done. (0.010s)
# image 216/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89002.jpg: 480x640 Done. (0.010s)
# image 217/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89673.jpg: 480x640 Done. (0.010s)
# image 218/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/8968.jpg: 480x640 Done. (0.011s)
# image 219/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90027.jpg: 480x640 Done. (0.012s)
# image 220/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90070.jpg: 480x640 Done. (0.011s)
# image 221/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/9019.jpg: 480x640 Done. (0.010s)
# image 222/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90293.jpg: 480x640 Done. (0.011s)
# image 223/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90470.jpg: 480x640 Done. (0.011s)
# image 224/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90502.jpg: 480x640 Done. (0.011s)
# image 225/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90844.jpg: 480x640 Done. (0.011s)
# image 226/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90847.jpg: 480x640 Done. (0.011s)
# image 227/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90946.jpg: 480x640 Done. (0.012s)
# image 228/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/91321.jpg: 480x640 Done. (0.014s)
# image 229/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/91640.jpg: 480x640 Done. (0.012s)
# image 230/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/91663.jpg: 480x640 Done. (0.011s)
# image 231/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/92136.jpg: 480x640 Done. (0.011s)
# image 232/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/9468.jpg: 480x640 Done. (0.013s)
# image 233/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/94728.jpg: 480x640 Done. (0.012s)
# image 234/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/9523.jpg: 480x640 Done. (0.011s)
# image 235/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/95357.jpg: 480x640 Done. (0.011s)
# image 236/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/95376.jpg: 480x640 Done. (0.011s)
# image 237/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/95378.jpg: 480x640 Done. (0.011s)
# image 238/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/9629.jpg: 480x640 Done. (0.011s)
# image 239/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96300.jpg: 480x640 Done. (0.011s)
# image 240/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96701.jpg: 480x640 Done. (0.011s)
# image 241/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96789.jpg: 480x640 Done. (0.011s)
# image 242/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96822.jpg: 480x640 Done. (0.011s)
# image 243/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97022.jpg: 480x640 Done. (0.011s)
# image 244/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97060.jpg: 480x640 Done. (0.010s)
# image 245/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/9717.jpg: 480x640 Done. (0.012s)
# image 246/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97362.jpg: 480x640 Done. (0.016s)
# image 247/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97567.jpg: 480x640 Done. (0.011s)
# image 248/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/98318.jpg: 480x640 Done. (0.015s)
# image 249/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/99106.jpg: 480x640 Done. (0.011s)
# image 250/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/99524.jpg: 480x640 Done. (0.013s)
# Speed: 0.6ms pre-process, 10.9ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# 8 labels saved to runs/detect/exp/labels

# %%
# find images that have detections 
images_with_labels = [int(x.replace('.txt', '')) for x in os.listdir(os.path.join(project, name, 'labels'))]
potential_images.loc[images_with_labels]
# Out:
#        Unnamed: 0                                          input_img  latitude  longitude  being_labeled country            admin1 admin2  cc    location  test_set                       time  focal_length  pixel_height
# 61385       61385  gs://street2sat-uploaded/KENYA/2021_07_07_T2/G...  0.625876  35.312018          False   KENYA       Uasin Gishu    NaN  KE     Eldoret     False  2021-07-07 09:03:03+00:00             3          2028
# 21251       21251  gs://street2sat-uploaded/KENYA/2021-07-17-T1/G... -0.679134  34.723568          False   KENYA             Kisii    NaN  KE       Kisii     False  2021-07-17 13:36:12+00:00             3          2028
# 26107       26107  gs://street2sat-uploaded/KENYA/2021-07-21-T1/G... -0.756776  34.875893          False   KENYA  Nyamira District    NaN  KE      Keroka     False  2021-07-21 14:01:31+00:00             3          2028
# 25418       25418  gs://street2sat-uploaded/KENYA/2021-07-21-T1/G... -0.759381  34.878410          False   KENYA  Nyamira District    NaN  KE      Keroka     False  2021-07-21 13:15:04+00:00             3          2028
# 79276       79276  gs://street2sat-uploaded/KENYA/2021_07_13_T2/1...  1.190970  34.997915          False   KENYA        West Pokot    NaN  KE  Kapenguria     False  2021-07-13 10:45:13+00:00             3          2028
# 24019       24019  gs://street2sat-uploaded/KENYA/2021-07-18-T1/G... -0.748092  34.782035          False   KENYA             Kisii    NaN  KE       Kisii     False  2021-07-18 15:19:51+00:00             3          2028
# 64191       64191  gs://street2sat-uploaded/KENYA/2021_07_10_T2/1...  0.781988  34.565132          False   KENYA               NaN    NaN  KE    Malikisi     False  2021-07-10 11:46:00+00:00             3          2028
# 21068       21068  gs://street2sat-uploaded/KENYA/2021-07-17-T1/G... -0.679199  34.731849          False   KENYA             Kisii    NaN  KE       Kisii     False  2021-07-17 13:31:16+00:00             3          2028

# %%
# Generate CSV, find detected images in the directory 
# these contain the txt files of labels that detect.py found, if the class was not 
# present it will not be in this directory
images_with_labels = [int(x.replace('.txt', '')) for x in os.listdir(os.path.join(project, name, 'labels'))]

# filter the potential images to label by the ones which were detected 
images_of_interest = potential_images.loc[images_with_labels]

print(f"Found {len(images_of_interest)} images")

# create csv with each row having the image path from potential images 
amount_of_csvs_to_generate = 1
for i in tqdm(range(amount_of_csvs_to_generate), desc="CSV Generation"):
    images_to_label = images_of_interest
    csv_name = datetime.now().strftime("%Y-%m-%d_%H-%M-%S_") + f'crop_{query_for_crop}_region_{query_for_region}' + '.csv'
    print(f"Saving to {csv_name}")
    df = pd.DataFrame(images_to_label)
    df.to_csv(f"gs://{gcloud_labeling_bucket_str}/{csv_name}", sep="\n", index=False, header=False)
# Out:
# 67
# CSV Generation:   0%|          | 0/1 [00:00<?, ?it/s]
# Saving to 2022-03-15_11-34-02_crop_banana_region_UG.csv
# CSV Generation: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]

# %%
# location of csv in google cloud 
f"gs://{gcloud_labeling_bucket_str}/{csv_name}"
# Out:
# 'gs://street2sat-gcloud-labeling/2022-03-15_11-34-02_crop_banana_region_UG.csv'

# %%
# create dataset 
ds = aiplatform.ImageDataset.create(
        display_name=csv_name.split('.')[0],
        gcs_source=f"gs://{gcloud_labeling_bucket_str}/{csv_name}",
        import_schema_uri=aiplatform.schema.dataset.ioformat.image.bounding_box,
        sync=False,
    )
# Out:
# INFO:google.cloud.aiplatform.datasets.dataset:Creating ImageDataset
# INFO:google.cloud.aiplatform.datasets.dataset:Create ImageDataset backing LRO: projects/1012768714927/locations/us-central1/datasets/9121113057425096704/operations/4717991819122573312
