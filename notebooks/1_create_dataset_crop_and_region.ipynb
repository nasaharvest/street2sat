# %%
from google.cloud import firestore
from google.cloud import storage, aiplatform
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from yolov5 import detect
import sys
import yaml
import os
import shutil
import reverse_geocoder as rg
import random
from tqdm import tqdm
import collections
from datetime import datetime

# Initialize connections to cloud storage and database
# !gcloud auth login
# !gcloud config set account <>
# !gcloud config set project bsos-geog-harvest1
# !gcloud auth application-default login

# %% [markdown]
# # Create Dataset Based On Crop And Region
#
# **Author:** Madhava Paliyam (madhavapaliyam@gmail.com)
#
# **Description:** Creates a dataset based on a crop or region that we want to improve in. This should be used after running notebook 4_analyze_predictions.ipynb so that a region/crop combinations that is performing poorly can be queried for additional images and labeled to improve the model.
#
#
#
# **Inputs**: Parameters for yolov5 detection, region to query, crop to query
#
# **Outputs**: A dataset onto gs://street2sat-gcloud-labeling bucket with dataset and AI platform dataset.

# %%
# !dvc pull -q -f

# %% [markdown]
# ### 1. Sampling dataset

# %%
##### SET DATASET QUERY PARAMETERS HERE #####
query_for_crop = 'banana'   # choose from any of the available crops
country_code = 'KE'         # choose from country code : 'KE', 'UG', 'US'
images_to_search = 250
###############################

# %%
# read csv 
all_paths = pd.read_csv('gs://street2sat-database-csv/database-info.csv')
# we want images not already being labeled
all_paths = all_paths[all_paths['being_labeled'] == False]
# and also images that are not in test set 
all_paths = all_paths[all_paths['test_set'] == False]
# Out:
# /home/paliyamm/.conda/envs/lacuna/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# randomly sample images within country
potential_images = all_paths[all_paths['cc'] == country_code].sample(images_to_search)
potential_images.head()
# Out:
#         Unnamed: 0                                          input_img  latitude  longitude  being_labeled  ... location test_set                       time focal_length pixel_height
# 126533      126533  gs://street2sat-uploaded/KENYA/2021_08_02_T2/1...  0.540532  34.793166          False  ...   Webuye    False  2021-08-03 11:36:00+00:00            3         2028
# 47188        47188  gs://street2sat-uploaded/KENYA/2021-07-31-T1/G... -0.699790  35.173365          False  ...    Sotik    False  2021-07-31 15:42:19+00:00            3         2028
# 106009      106009  gs://street2sat-uploaded/KENYA/2021_07_18_T2/1...  0.668875  34.298004          False  ...   Malaba    False  2021-07-18 14:31:48+00:00            3         2028
# 112140      112140  gs://street2sat-uploaded/KENYA/2021_07_19_T2/1...  0.049900  34.449049          False  ...     Yala    False  2021-07-19 14:27:12+00:00            3         2028
# 108934      108934  gs://street2sat-uploaded/KENYA/2021_07_19_T2/1...  0.263277  34.095297          False  ...   Luanda    False  2021-07-19 12:08:20+00:00            3         2028
#
# [5 rows x 14 columns]

# %%
# open connection to google cloud 
client = storage.Client()
gcloud_uploaded_bucket_str = 'street2sat-uploaded'
gcloud_uploaded_bucket = client.bucket(gcloud_uploaded_bucket_str)


classes_dict = {}
with open('../street2sat_utils/crop_info/classes.txt') as classes_file: 
    for i, line in enumerate(classes_file):
        classes_dict[line.strip()] = i

# %%
# create directory to save images to 
save_dir = os.path.join(f'crop_{query_for_crop}_region_{country_code}')
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
# download images 
for i,item in potential_images.iterrows(): 
    blob = gcloud_uploaded_bucket.blob(item['input_img'].replace('gs://street2sat-uploaded/', ''))
    blob.download_to_filename(os.path.join(save_dir, f"{i}.jpg"))

# %% [markdown]
# ### 2. Run detect.py
#
# Configure conf_thres and iou_thres to adjust the amount/quality of bounding boxes returned.

# %%
##### MODIFY THESE AS NEEDED #####
conf_thres = 0.05                  # confidence threshold
iou_thres = 0.05                   # NMS IOU threshold
weights= '/gpfs/data1/cmongp1/mpaliyam/street2sat/yolov5/runs/train/exp18/weights/best.pt'   # model.pt path(s)
imgsz= 640                         # inference size (height, width)
max_det = 1000                     # maximum detections per image
project = 'runs/detect'            # save results to project/name
name ='exp'                        # save results to project/name
######################################


# runs the detect script from yolov5 libary
to_parse = f"detect.py " \
            + f"--weights {weights} " \
            + f"--source {save_dir} " \
            + f"--imgsz {imgsz} " \
            + f"--conf-thres {conf_thres} " \
            + f"--iou-thres {iou_thres} " \
            + f"--classes {classes_dict[query_for_crop]} " \
            + f"--max-det {max_det} " \
            + f"--project {project} " \
            + f"--name {name} " \
            + f"--exist-ok " \
            + f"--save-crop " \
            + f"--save-txt " \
            + f"--save-conf " \

to_parse = to_parse.split()
sys.argv = to_parse 
detect.main()
# Out:
# detect: weights=['/gpfs/data1/cmongp1/mpaliyam/street2sat/yolov5/runs/train/exp18/weights/best.pt'], source=crop_banana_region_KE, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.05, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=True, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# INFO:yolov5.utils.torch_utils:YOLOv5 🚀 2022-2-16 torch 1.10.2+cu102 CUDA:0 (Tesla V100-PCIE-16GB, 16160.5MB)
#
# INFO:models.yolo:Fusing layers...
# INFO:yolov5.utils.torch_utils:Model Summary: 369 layers, 20919810 parameters, 0 gradients, 48.2 GFLOPs
# /home/paliyamm/.conda/envs/lacuna/lib/python3.7/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/100295.jpg: 480x640 Done. (0.012s)
# image 2/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/100441.jpg: 480x640 Done. (0.010s)
# image 3/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/101347.jpg: 480x640 Done. (0.010s)
# image 4/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/101705.jpg: 480x640 Done. (0.010s)
# image 5/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/101715.jpg: 480x640 Done. (0.010s)
# image 6/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/102031.jpg: 480x640 Done. (0.010s)
# image 7/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/102191.jpg: 480x640 Done. (0.010s)
# image 8/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/103661.jpg: 480x640 Done. (0.010s)
# image 9/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/103776.jpg: 480x640 Done. (0.009s)
# image 10/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104039.jpg: 480x640 Done. (0.010s)
# image 11/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104180.jpg: 480x640 Done. (0.009s)
# image 12/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104685.jpg: 480x640 Done. (0.010s)
# image 13/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104687.jpg: 480x640 Done. (0.010s)
# image 14/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/104758.jpg: 480x640 Done. (0.010s)
# image 15/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105085.jpg: 480x640 Done. (0.008s)
# image 16/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105228.jpg: 480x640 Done. (0.009s)
# image 17/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/105478.jpg: 480x640 Done. (0.010s)
# image 18/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106009.jpg: 480x640 Done. (0.009s)
# image 19/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/10652.jpg: 480x640 Done. (0.010s)
# image 20/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106559.jpg: 480x640 Done. (0.009s)
# image 21/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/106606.jpg: 480x640 Done. (0.009s)
# image 22/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/107125.jpg: 480x640 Done. (0.009s)
# image 23/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108421.jpg: 480x640 Done. (0.009s)
# image 24/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108490.jpg: 480x640 Done. (0.009s)
# image 25/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108550.jpg: 480x640 Done. (0.009s)
# image 26/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108597.jpg: 480x640 Done. (0.009s)
# image 27/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/108934.jpg: 480x640 Done. (0.009s)
# image 28/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/109680.jpg: 480x640 Done. (0.009s)
# image 29/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/109857.jpg: 480x640 Done. (0.010s)
# image 30/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/110164.jpg: 480x640 Done. (0.010s)
# image 31/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/110457.jpg: 480x640 Done. (0.010s)
# image 32/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/110763.jpg: 480x640 Done. (0.009s)
# image 33/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/111258.jpg: 480x640 Done. (0.010s)
# image 34/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112140.jpg: 480x640 Done. (0.009s)
# image 35/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112323.jpg: 480x640 Done. (0.009s)
# image 36/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112661.jpg: 480x640 Done. (0.009s)
# image 37/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112760.jpg: 480x640 Done. (0.010s)
# image 38/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112784.jpg: 480x640 Done. (0.009s)
# image 39/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112811.jpg: 480x640 Done. (0.009s)
# image 40/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/112854.jpg: 480x640 Done. (0.010s)
# image 41/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/11335.jpg: 480x640 Done. (0.009s)
# image 42/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/11354.jpg: 480x640 Done. (0.009s)
# image 43/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/113728.jpg: 480x640 Done. (0.009s)
# image 44/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/114527.jpg: 480x640 Done. (0.009s)
# image 45/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115308.jpg: 480x640 Done. (0.009s)
# image 46/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115475.jpg: 480x640 Done. (0.010s)
# image 47/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115528.jpg: 480x640 Done. (0.009s)
# image 48/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/11561.jpg: 480x640 Done. (0.009s)
# image 49/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115819.jpg: 480x640 Done. (0.009s)
# image 50/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115854.jpg: 480x640 Done. (0.009s)
# image 51/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115865.jpg: 480x640 Done. (0.009s)
# image 52/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/115984.jpg: 480x640 Done. (0.009s)
# image 53/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/117079.jpg: 480x640 Done. (0.009s)
# image 54/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/117949.jpg: 480x640 Done. (0.009s)
# image 55/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/118218.jpg: 480x640 Done. (0.009s)
# image 56/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/119392.jpg: 480x640 Done. (0.009s)
# image 57/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/12007.jpg: 480x640 Done. (0.009s)
# image 58/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/120367.jpg: 480x640 Done. (0.009s)
# image 59/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/120586.jpg: 480x640 Done. (0.010s)
# image 60/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/122457.jpg: 480x640 Done. (0.008s)
# image 61/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123100.jpg: 480x640 Done. (0.010s)
# image 62/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123275.jpg: 480x640 Done. (0.009s)
# image 63/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123429.jpg: 480x640 Done. (0.010s)
# image 64/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/123853.jpg: 480x640 Done. (0.010s)
# image 65/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/124184.jpg: 480x640 Done. (0.010s)
# image 66/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/125395.jpg: 480x640 Done. (0.009s)
# image 67/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/125415.jpg: 480x640 Done. (0.010s)
# image 68/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/125491.jpg: 480x640 Done. (0.009s)
# image 69/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/126173.jpg: 480x640 Done. (0.009s)
# image 70/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/126533.jpg: 480x640 Done. (0.009s)
# image 71/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127223.jpg: 480x640 Done. (0.009s)
# image 72/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127279.jpg: 480x640 Done. (0.009s)
# image 73/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/127818.jpg: 480x640 Done. (0.009s)
# image 74/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128228.jpg: 480x640 Done. (0.010s)
# image 75/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128549.jpg: 480x640 Done. (0.010s)
# image 76/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128597.jpg: 480x640 Done. (0.009s)
# image 77/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128601.jpg: 480x640 Done. (0.010s)
# image 78/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/12873.jpg: 480x640 Done. (0.009s)
# image 79/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/128786.jpg: 480x640 Done. (0.009s)
# image 80/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/129208.jpg: 480x640 Done. (0.009s)
# image 81/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/129484.jpg: 480x640 Done. (0.009s)
# image 82/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/129505.jpg: 480x640 Done. (0.009s)
# image 83/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/129763.jpg: 480x640 Done. (0.010s)
# image 84/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/129791.jpg: 480x640 Done. (0.009s)
# image 85/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/131256.jpg: 480x640 Done. (0.009s)
# image 86/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/131380.jpg: 480x640 Done. (0.010s)
# image 87/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/13833.jpg: 480x640 Done. (0.009s)
# image 88/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/14476.jpg: 480x640 Done. (0.009s)
# image 89/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/15105.jpg: 480x640 Done. (0.009s)
# image 90/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1680.jpg: 480x640 Done. (0.009s)
# image 91/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17582.jpg: 480x640 Done. (0.009s)
# image 92/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17650.jpg: 480x640 Done. (0.009s)
# image 93/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17709.jpg: 480x640 Done. (0.010s)
# image 94/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1790.jpg: 480x640 Done. (0.010s)
# image 95/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/17923.jpg: 480x640 Done. (0.009s)
# image 96/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/18011.jpg: 480x640 Done. (0.009s)
# image 97/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/18277.jpg: 480x640 Done. (0.009s)
# image 98/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/1887.jpg: 480x640 Done. (0.009s)
# image 99/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/19449.jpg: 480x640 Done. (0.009s)
# image 100/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20345.jpg: 480x640 4 bananas, Done. (0.009s)
# image 101/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20746.jpg: 480x640 Done. (0.009s)
# image 102/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/20891.jpg: 480x640 Done. (0.009s)
# image 103/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/22579.jpg: 480x640 Done. (0.009s)
# image 104/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/22816.jpg: 480x640 Done. (0.009s)
# image 105/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/26113.jpg: 480x640 1 banana, Done. (0.010s)
# image 106/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/27885.jpg: 480x640 Done. (0.010s)
# image 107/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/28627.jpg: 480x640 Done. (0.010s)
# image 108/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/28791.jpg: 480x640 Done. (0.010s)
# image 109/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/28944.jpg: 480x640 Done. (0.010s)
# image 110/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/30587.jpg: 480x640 Done. (0.009s)
# image 111/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/31344.jpg: 480x640 Done. (0.009s)
# image 112/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/31527.jpg: 480x640 Done. (0.009s)
# image 113/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/32595.jpg: 480x640 Done. (0.009s)
# image 114/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/328.jpg: 480x640 Done. (0.009s)
# image 115/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33085.jpg: 480x640 Done. (0.009s)
# image 116/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33240.jpg: 480x640 Done. (0.008s)
# image 117/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33352.jpg: 480x640 Done. (0.009s)
# image 118/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33645.jpg: 480x640 Done. (0.009s)
# image 119/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33718.jpg: 480x640 Done. (0.009s)
# image 120/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/33899.jpg: 480x640 Done. (0.009s)
# image 121/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3600.jpg: 480x640 Done. (0.010s)
# image 122/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3603.jpg: 480x640 Done. (0.009s)
# image 123/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/3656.jpg: 480x640 Done. (0.009s)
# image 124/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/36902.jpg: 480x640 Done. (0.009s)
# image 125/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/36963.jpg: 480x640 Done. (0.009s)
# image 126/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/37184.jpg: 480x640 Done. (0.009s)
# image 127/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/37956.jpg: 480x640 Done. (0.010s)
# image 128/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/39280.jpg: 480x640 Done. (0.009s)
# image 129/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/39506.jpg: 480x640 Done. (0.009s)
# image 130/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/41404.jpg: 480x640 Done. (0.008s)
# image 131/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/43323.jpg: 480x640 Done. (0.009s)
# image 132/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/43593.jpg: 480x640 Done. (0.009s)
# image 133/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/4364.jpg: 480x640 Done. (0.009s)
# image 134/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/43813.jpg: 480x640 Done. (0.010s)
# image 135/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/4449.jpg: 480x640 Done. (0.010s)
# image 136/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/45355.jpg: 480x640 Done. (0.010s)
# image 137/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/4568.jpg: 480x640 Done. (0.009s)
# image 138/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/45803.jpg: 480x640 Done. (0.009s)
# image 139/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/4608.jpg: 480x640 Done. (0.010s)
# image 140/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/47025.jpg: 480x640 Done. (0.008s)
# image 141/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/47173.jpg: 480x640 Done. (0.010s)
# image 142/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/47188.jpg: 480x640 Done. (0.010s)
# image 143/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/48860.jpg: 480x640 Done. (0.009s)
# image 144/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/49185.jpg: 480x640 Done. (0.009s)
# image 145/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/49965.jpg: 480x640 Done. (0.010s)
# image 146/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/49966.jpg: 480x640 Done. (0.009s)
# image 147/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/49985.jpg: 480x640 Done. (0.010s)
# image 148/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/50306.jpg: 480x640 Done. (0.009s)
# image 149/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/51013.jpg: 480x640 Done. (0.009s)
# image 150/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/51692.jpg: 480x640 Done. (0.009s)
# image 151/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/51779.jpg: 480x640 Done. (0.010s)
# image 152/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/52142.jpg: 480x640 Done. (0.009s)
# image 153/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/52749.jpg: 480x640 Done. (0.009s)
# image 154/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/5308.jpg: 480x640 Done. (0.009s)
# image 155/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/53183.jpg: 480x640 Done. (0.010s)
# image 156/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/54352.jpg: 480x640 Done. (0.010s)
# image 157/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/54801.jpg: 480x640 Done. (0.010s)
# image 158/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/54815.jpg: 480x640 Done. (0.010s)
# image 159/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/55066.jpg: 480x640 Done. (0.010s)
# image 160/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/55176.jpg: 480x640 Done. (0.009s)
# image 161/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/56055.jpg: 480x640 Done. (0.009s)
# image 162/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/56430.jpg: 480x640 Done. (0.009s)
# image 163/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/56910.jpg: 480x640 Done. (0.009s)
# image 164/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/57041.jpg: 480x640 Done. (0.009s)
# image 165/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/57043.jpg: 480x640 Done. (0.009s)
# image 166/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/60735.jpg: 480x640 Done. (0.009s)
# image 167/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/61201.jpg: 480x640 Done. (0.010s)
# image 168/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/61360.jpg: 480x640 Done. (0.009s)
# image 169/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/61801.jpg: 480x640 Done. (0.009s)
# image 170/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6306.jpg: 480x640 Done. (0.010s)
# image 171/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/63181.jpg: 480x640 Done. (0.010s)
# image 172/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/63365.jpg: 480x640 Done. (0.009s)
# image 173/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/63414.jpg: 480x640 Done. (0.009s)
# image 174/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/64082.jpg: 480x640 1 banana, Done. (0.009s)
# image 175/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65204.jpg: 480x640 Done. (0.009s)
# image 176/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65395.jpg: 480x640 Done. (0.009s)
# image 177/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/6549.jpg: 480x640 Done. (0.010s)
# image 178/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65842.jpg: 480x640 Done. (0.009s)
# image 179/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/65936.jpg: 480x640 Done. (0.009s)
# image 180/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/66835.jpg: 480x640 Done. (0.009s)
# image 181/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/67482.jpg: 480x640 Done. (0.009s)
# image 182/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/67493.jpg: 480x640 Done. (0.009s)
# image 183/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/68134.jpg: 480x640 Done. (0.010s)
# image 184/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/68609.jpg: 480x640 Done. (0.009s)
# image 185/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/69617.jpg: 480x640 Done. (0.009s)
# image 186/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/69735.jpg: 480x640 Done. (0.009s)
# image 187/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/70539.jpg: 480x640 Done. (0.009s)
# image 188/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71139.jpg: 480x640 Done. (0.009s)
# image 189/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71283.jpg: 480x640 Done. (0.009s)
# image 190/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/71760.jpg: 480x640 Done. (0.009s)
# image 191/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/72744.jpg: 480x640 Done. (0.009s)
# image 192/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/7285.jpg: 480x640 Done. (0.009s)
# image 193/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/73418.jpg: 480x640 Done. (0.010s)
# image 194/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/73542.jpg: 480x640 Done. (0.009s)
# image 195/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74029.jpg: 480x640 Done. (0.010s)
# image 196/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74076.jpg: 480x640 Done. (0.009s)
# image 197/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/7454.jpg: 480x640 Done. (0.009s)
# image 198/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/74725.jpg: 480x640 Done. (0.010s)
# image 199/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75115.jpg: 480x640 Done. (0.009s)
# image 200/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75596.jpg: 480x640 Done. (0.010s)
# image 201/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75768.jpg: 480x640 Done. (0.009s)
# image 202/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/75874.jpg: 480x640 Done. (0.009s)
# image 203/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76119.jpg: 480x640 Done. (0.009s)
# image 204/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/76912.jpg: 480x640 Done. (0.010s)
# image 205/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/77000.jpg: 480x640 Done. (0.010s)
# image 206/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/77255.jpg: 480x640 Done. (0.009s)
# image 207/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/77699.jpg: 480x640 Done. (0.009s)
# image 208/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/78122.jpg: 480x640 Done. (0.009s)
# image 209/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79062.jpg: 480x640 Done. (0.010s)
# image 210/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79180.jpg: 480x640 Done. (0.009s)
# image 211/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79264.jpg: 480x640 Done. (0.009s)
# image 212/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/79401.jpg: 480x640 Done. (0.010s)
# image 213/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/80209.jpg: 480x640 Done. (0.009s)
# image 214/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/80434.jpg: 480x640 Done. (0.009s)
# image 215/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/80511.jpg: 480x640 Done. (0.010s)
# image 216/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/81293.jpg: 480x640 Done. (0.009s)
# image 217/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/8630.jpg: 480x640 Done. (0.009s)
# image 218/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/86371.jpg: 480x640 Done. (0.009s)
# image 219/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/87432.jpg: 480x640 Done. (0.009s)
# image 220/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/87622.jpg: 480x640 Done. (0.010s)
# image 221/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/87987.jpg: 480x640 Done. (0.012s)
# image 222/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88036.jpg: 480x640 Done. (0.009s)
# image 223/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88739.jpg: 480x640 Done. (0.009s)
# image 224/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/88992.jpg: 480x640 Done. (0.010s)
# image 225/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89205.jpg: 480x640 Done. (0.009s)
# image 226/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89251.jpg: 480x640 Done. (0.009s)
# image 227/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89417.jpg: 480x640 Done. (0.009s)
# image 228/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89464.jpg: 480x640 Done. (0.009s)
# image 229/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89657.jpg: 480x640 Done. (0.009s)
# image 230/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/89701.jpg: 480x640 Done. (0.009s)
# image 231/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90158.jpg: 480x640 Done. (0.009s)
# image 232/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90559.jpg: 480x640 Done. (0.009s)
# image 233/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/90785.jpg: 480x640 Done. (0.009s)
# image 234/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/92028.jpg: 480x640 Done. (0.009s)
# image 235/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/92220.jpg: 480x640 Done. (0.010s)
# image 236/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/92378.jpg: 480x640 Done. (0.010s)
# image 237/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/93034.jpg: 480x640 Done. (0.010s)
# image 238/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/93211.jpg: 480x640 Done. (0.010s)
# image 239/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/93228.jpg: 480x640 Done. (0.011s)
# image 240/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/94886.jpg: 480x640 Done. (0.010s)
# image 241/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/95210.jpg: 480x640 Done. (0.009s)
# image 242/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/95941.jpg: 480x640 Done. (0.010s)
# image 243/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96055.jpg: 480x640 Done. (0.010s)
# image 244/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96259.jpg: 480x640 Done. (0.010s)
# image 245/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/96915.jpg: 480x640 Done. (0.009s)
# image 246/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97330.jpg: 480x640 Done. (0.010s)
# image 247/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/97977.jpg: 480x640 Done. (0.009s)
# image 248/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/98272.jpg: 480x640 Done. (0.009s)
# image 249/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/98557.jpg: 480x640 Done. (0.009s)
# image 250/250 /gpfs/data1/cmongp1/mpaliyam/street2sat/street2sat/notebooks/crop_banana_region_KE/98705.jpg: 480x640 Done. (0.009s)
# Speed: 0.4ms pre-process, 9.4ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# 3 labels saved to runs/detect/exp/labels

# %% [markdown]
# ### 3. Save Dataset to Google Cloud for labeling

# %%
# find images that have detections 
images_with_labels = [int(x.replace('.txt', '')) for x in os.listdir(os.path.join(project, name, 'labels'))]
potential_images.loc[images_with_labels]
# Out:
#        Unnamed: 0                                          input_img  latitude  longitude  being_labeled  ...  location test_set                       time focal_length pixel_height
# 64082       64082  gs://street2sat-uploaded/KENYA/2021_07_10_T2/1...  0.785105  34.567473          False  ...  Malikisi    False  2021-07-10 11:45:06+00:00            3         2028
# 26113       26113  gs://street2sat-uploaded/KENYA/2021-07-21-T1/G... -0.756797  34.875908          False  ...    Keroka    False  2021-07-21 14:01:34+00:00            3         2028
# 20345       20345  gs://street2sat-uploaded/KENYA/2021-07-17-T1/G... -0.668167  34.750041          False  ...     Kisii    False  2021-07-17 13:11:27+00:00            3         2028
#
# [3 rows x 14 columns]

# %%
# Generate CSV, find detected images in the directory 
# these contain the txt files of labels that detect.py found, if the class was not 
# present it will not be in this directory
gcloud_labeling_bucket_str = 'street2sat-gcloud-labeling'
images_with_labels = [int(x.replace('.txt', '')) for x in os.listdir(os.path.join(project, name, 'labels'))]

# filter the potential images to label by the ones which were detected 
images_of_interest = potential_images.loc[images_with_labels]

print(f"Found {len(images_of_interest)} images")

# create csv with each row having the image path from potential images 
amount_of_csvs_to_generate = 1
for i in tqdm(range(amount_of_csvs_to_generate), desc="CSV Generation"):
    images_to_label = images_of_interest
    csv_name = datetime.now().strftime("%Y-%m-%d_%H-%M-%S_") + f'crop_{query_for_crop}_region_{query_for_region}' + '.csv'
    print(f"Saving to {csv_name}")
    df = pd.DataFrame(images_to_label)
    df.to_csv(f"gs://{gcloud_labeling_bucket_str}/{csv_name}", sep="\n", index=False, header=False)
# Out:
# 67
# CSV Generation:   0%|          | 0/1 [00:00<?, ?it/s]
# Saving to 2022-03-15_11-34-02_crop_banana_region_UG.csv
# CSV Generation: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]

# %%
# location of csv in google cloud 
f"gs://{gcloud_labeling_bucket_str}/{csv_name}"
# Out:
# 'gs://street2sat-gcloud-labeling/2022-03-15_11-34-02_crop_banana_region_UG.csv'

# %%
# create dataset 
ds = aiplatform.ImageDataset.create(
        display_name=csv_name.split('.')[0],
        gcs_source=f"gs://{gcloud_labeling_bucket_str}/{csv_name}",
        import_schema_uri=aiplatform.schema.dataset.ioformat.image.bounding_box,
        sync=False,
    )
# Out:
# INFO:google.cloud.aiplatform.datasets.dataset:Creating ImageDataset
# INFO:google.cloud.aiplatform.datasets.dataset:Create ImageDataset backing LRO: projects/1012768714927/locations/us-central1/datasets/9121113057425096704/operations/4717991819122573312
